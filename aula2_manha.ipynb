# %%
import pandas
titanic = pandas.read_csv("titanic_1_aula.csv")

# %%
titanic.Survived[titanic["Survived"]==0].count()
# Out:
# 549

# %%
titanic.Survived[titanic["Survived"]==1].count()
# Out:
# 342

# %%
def calculate_percentage(val,total):
    """ Calculates the percentage of a value over a total"""
    percent = float (val/total)
    beautiful_percent = "{:.2f}%".format(percent*100)
    return beautiful_percent

# %%
total = titanic.Survived.count()
nao_sobreviveu = titanic.Survived[titanic["Survived"]==0].count()
sobreviveu = titanic.Survived[titanic["Survived"]==1].count()

# %%
print(calculate_percentage(sobreviveu, total))
# Out:
# 38.38%

# %%
print(calculate_percentage(nao_sobreviveu, total))
# Out:
# 61.62%

# %%
sem_familia = titanic.Survived[titanic["Relatives"]== 0].count()
com_familia = titanic.Survived[titanic["Relatives"] > 0].count()

print(calculate_percentage(sem_familia, total))
print(calculate_percentage(com_familia, total))
# Out:
# 60.27%
# 39.73%

# %%
mortos = titanic[titanic["Survived"]==0]

# %%
mortos_sem_familia = mortos.Survived[titanic["Relatives"]==0].count()
mortos_sem_familia
# Out:
# 374

# %%
mortos_com_familia = mortos.Survived[titanic["Relatives"] > 0].count()
mortos_com_familia
# Out:
# 175

# %%
print("nao sobreviveu que nao tem familia no barco", calculate_percentage(mortos_sem_familia, nao_sobreviveu))
print("nao sobreviveu que tem familia no barco", calculate_percentage(mortos_com_familia, nao_sobreviveu))
# Out:
# nao sobreviveu que nao tem familia no barco 68.12%
# nao sobreviveu que tem familia no barco 31.88%

# %%
vivos = titanic[titanic["Survived"]==1]
vivos_sem_familia = vivos.Survived[titanic["Relatives"] == 0].count()
vivos_sem_familia
# Out:
# 163

# %%
vivos_com_familia = vivos.Survived[titanic["Relatives"] > 0].count()
vivos_com_familia
# Out:
# 179

# %%
print("sobreviventes que nao tem familia no barco", calculate_percentage(vivos_sem_familia, sobreviveu))
print("sobreviventes que tem familia no barco", calculate_percentage(vivos_com_familia, sobreviveu))
# Out:
# sobreviventes que nao tem familia no barco 47.66%
# sobreviventes que tem familia no barco 52.34%

# %%
male = titanic.Survived[titanic["Sex"]=="male"].count()
female = titanic.Survived[titanic["Sex"]=="female"].count()

print(calculate_percentage(male, total))
print(calculate_percentage(female, total))
# Out:
# 64.76%
# 35.24%

# %%
mortos_homem = mortos.Survived[titanic["Sex"]=="male"].count()
mortos_homem
# Out:
# 468

# %%
mortos_mulher = mortos.Survived[titanic["Sex"]=="female"].count()
mortos_mulher
# Out:
# 81

# %%
print("nao sobreviveu do sexo masculino", calculate_percentage(mortos_homem, nao_sobreviveu))
print("nao sobreviveu do sexo feminino", calculate_percentage(mortos_mulher, nao_sobreviveu))
# Out:
# nao sobreviveu do sexo masculino 85.25%
# nao sobreviveu do sexo feminino 14.75%

# %%
vivos_homem = vivos.Survived[titanic["Sex"]=="male"].count()
vivos_homem
# Out:
# 109

# %%
vivos_mulher = vivos.Survived[titanic["Sex"]=="female"].count()
vivos_mulher
# Out:
# 233

# %%
print("sobreviveu do sexo masculino", calculate_percentage(vivos_homem, sobreviveu))
print("sobreviveu do sexo feminino", calculate_percentage(vivos_mulher, sobreviveu))
# Out:
# sobreviveu do sexo masculino 31.87%
# sobreviveu do sexo feminino 68.13%

# %%
#seleciono as classes primeiros
first = titanic.Survived[titanic["Pclass"]==1].count()
second = titanic.Survived[titanic["Pclass"]==2].count()
third = titanic.Survived[titanic["Pclass"]==3].count()

#os que sobreviveram
first_live = vivos.Survived[titanic["Pclass"]==1].sum()
second_live = vivos.Survived[titanic["Pclass"]==2].sum()
third_live = vivos.Survived[titanic["Pclass"]==3].sum()

print("primeira classe que sobreviveram: ", calculate_percentage(first_live, first))
print("segunda classe que sobreviveram: ", calculate_percentage(second_live, second))
print("terceira classe que sobreviveram: ", calculate_percentage(third_live, third))
# Out:
# primeira classe que sobreviveram:  62.96%
# segunda classe que sobreviveram:  47.28%
# terceira classe que sobreviveram:  24.24%

# %%
vivos
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 15            16         1       2
# 17            18         1       2
# 19            20         1       3
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 25            26         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 39            40         1       3
# 43            44         1       2
# 44            45         1       3
# 47            48         1       3
# 52            53         1       1
# 53            54         1       2
# 55            56         1       1
# ...

# %%
menor_de_idade = titanic[titanic["Age"] < 18]["Survived"].count()
maior_de_idade = titanic[titanic["Age"] >= 18]["Survived"].count()
terceira_idade = titanic[titanic["Age"] >= 60]["Survived"].count()


menor_de_idade_sobreviveram = vivos.Survived[titanic["Age"] < 18].sum()
maior_de_idade_sobreviveram = vivos.Survived[titanic["Age"] >= 18].sum()
terceira_idade_sobreviveram = vivos.Survived[titanic["Age"] >= 60].sum()

print("menor de idade que sobreviveram", calculate_percentage(menor_de_idade_sobreviveram, menor_idade))
print("maior de idade que sobreviveram", calculate_percentage(maior_de_idade_sobreviveram, menor_idade))
print("terceira idade que sobreviveram", calculate_percentage(terceira_idade_sobreviveram, terceira_idade))
# Out:
# menor de idade que sobreviveram 53.98%
# maior de idade que sobreviveram 202.65%
# terceira idade que sobreviveram 26.92%

# %%
#Transformando dados com apply

# Aplicando uma função aos dados para transformar a idade em faixas etarias
# O resultado do apply é uma serie

def faixa_etaria(linhas):
    idade = linhas["Age"]
    if idade < 10:
        return "criança"
    elif idade >= 10 and idade <18:
        return "adolescente"
    elif idade >=18 and idade <65:
        return "adulto"
    elif idade >= 65:
        return "idoso"
    else:
        return "nada"

# Criamos a coluna "faixa etaria" onde atribuimos o valor da serie
# resultante do apply
titanic["faixa_etaria"] = titanic.apply(faixa_etaria, axis=1)

# %%
titanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
mortos = titanic[titanic["Survived"]==0]
vivos = titanic[titanic["Survived"]==1]

# %%
mortos.Survived[titanic["faixa_etaria"]=="criança"].count()
# Out:
# 362

# %%
vivos.Survived[titanic["faixa_etaria"]=="criança"].count()
# Out:
# 38

# %%
mortos.Survived[titanic["faixa_etaria"]=="adolescente"].count()
# Out:
# 28

# %%
vivos.Survived[titanic["faixa_etaria"]=="adolescente"].count()
# Out:
# 23

# %%
mortos.Survived[titanic["faixa_etaria"]=="adulto"].count()
# Out:
# 362

# %%
vivos.Survived[titanic["faixa_etaria"]=="adulto"].count()
# Out:
# 228

# %%
filtro_mulher = titanic.Sex == "female"
filtro_crianca = titanic.faixa_etaria == "criança"

# %%
mortos.Survived[filtro_mulher | filtro_crianca].count()
# Out:
# 94

# %%
vivos.Survived[filtro_mulher | filtro_crianca].count()
# Out:
# 252

# %%
titanic_sem_age = titanic.drop(["Age", "Name"], axis=1)
titanic_sem_age.head()
# Out:
#    PassengerId  Survived  Pclass     Sex  SibSp  Parch            Ticket  \
# 0            1         0       3    male      1      0         A/5 21171
# 1            2         1       1  female      1      0          PC 17599
# 2            3         1       3  female      0      0  STON/O2. 3101282
# 3            4         1       1  female      1      0            113803
# 4            5         0       3    male      0      0            373450
#
#       Fare Cabin Embarked  Relatives faixa_etaria
# 0   7.2500   NaN        S          1       adulto
# 1  71.2833   C85        C          1       adulto
# 2   7.9250   NaN        S          0       adulto
# 3  53.1000  C123        S          1       adulto
# 4   8.0500   NaN        S          0       adulto

# %%
titanic.rename(columns={"faixa_etaria":"AgeRange"}, inplace=True)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Relatives AgeRange
# 0      0         A/5 21171   7.2500   NaN        S          1   adulto
# 1      0          PC 17599  71.2833   C85        C          1   adulto
# 2      0  STON/O2. 3101282   7.9250   NaN        S          0   adulto
# ...

# %%
titanic_sem_age.rename(columns={"faixa_etaria":"AgeRange"}, inplace=True)

# %%
titanic_sem_age.head(10)
# Out:
#    PassengerId  Survived  Pclass     Sex  SibSp  Parch            Ticket  \
# 0            1         0       3    male      1      0         A/5 21171
# 1            2         1       1  female      1      0          PC 17599
# 2            3         1       3  female      0      0  STON/O2. 3101282
# 3            4         1       1  female      1      0            113803
# 4            5         0       3    male      0      0            373450
# 5            6         0       3    male      0      0            330877
# 6            7         0       1    male      0      0             17463
# 7            8         0       3    male      3      1            349909
# 8            9         1       3  female      0      2            347742
# 9           10         1       2  female      1      0            237736
#
#       Fare Cabin Embarked  Relatives     AgeRange
# 0   7.2500   NaN        S          1       adulto
# 1  71.2833   C85        C          1       adulto
# ...

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Relatives        0
# AgeRange         0
# dtype: int64

# %%
titanic["Age"].isnull().head(20)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17     True
# 18    False
# 19     True
# Name: Age, dtype: bool

# %%
True + True
# Out:
# 2

# %%
False + False
# Out:
# 0

# %%
True + False
# Out:
# 1

# %%
sum([True, True, False])
# Out:
# 2

# %%
#indice se mantem e limpa os campos vazios
idades_nao_nulas = titanic["Age"].dropna()
idades_nao_nulas
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
# 6      54.0
# 7       2.0
# 8      27.0
# 9      14.0
# 10      4.0
# 11     58.0
# 12     20.0
# 13     39.0
# 14     14.0
# 15     55.0
# 16      2.0
# 18     31.0
# 20     35.0
# 21     34.0
# 22     15.0
# 23     28.0
# 24      8.0
# 25     38.0
# 27     19.0
# 30     40.0
# 33     66.0
# 34     28.0
# 35     42.0
# 37     21.0
# 38     18.0
#        ...
# 856    45.0
# 857    51.0
# 858    24.0
# 860    41.0
# 861    21.0
# 862    48.0
# 864    24.0
# 865    42.0
# 866    27.0
# 867    31.0
# 869     4.0
# 870    26.0
# 871    47.0
# 872    33.0
# 873    47.0
# 874    28.0
# 875    15.0
# 876    20.0
# 877    19.0
# 879    56.0
# 880    25.0
# 881    33.0
# 882    22.0
# 883    28.0
# 884    25.0
# 885    39.0
# 886    27.0
# 887    19.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 714, dtype: float64

# %%
qnt_idades_nulas_dropna = idades_nao_nulas.isnull().sum()
print("Quantidade de valores nulos: {}".format(qnt_idades_nulas_dropna))
# Out:
# Quantidade de valores nulos: 0

# %%
titanic["Age"].size #tamanho da serie
# Out:
# 891

# %%
titanic["Age"].count()
# Out:
# 714

# %%
idades_nao_nulas.size
# Out:
# 714

# %%
titanic["idades_nao_nulas"] = idades_nao_nulas
titanic[["idades_nao_nulas", "Age"]].head(10)
# Out:
#    idades_nao_nulas   Age
# 0              22.0  22.0
# 1              38.0  38.0
# 2              26.0  26.0
# 3              35.0  35.0
# 4              35.0  35.0
# 5               NaN   NaN
# 6              54.0  54.0
# 7               2.0   2.0
# 8              27.0  27.0
# 9              14.0  14.0

# %%
idades_nao_nulas.head(10)
# Out:
# 0     22.0
# 1     38.0
# 2     26.0
# 3     35.0
# 4     35.0
# 6     54.0
# 7      2.0
# 8     27.0
# 9     14.0
# 10     4.0
# Name: Age, dtype: float64

# %%
#preenche as idades nulas com -1
serie_idade_sem_nulo = titanic["Age"].fillna(-1)
serie_idade_sem_nulo.isnull().sum()
# Out:
# 0

# %%
serie_idade_sem_nulo.count()
# Out:
# 891

# %%
titanic["Age_fillna_1"]=serie_idade_sem_nulo

# %%
titanic["Age_fillna_1"].head(10)
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5    -1.0
# 6    54.0
# 7     2.0
# 8    27.0
# 9    14.0
# Name: Age_fillna_1, dtype: float64

# %%
# %matplotlib notebook
titanic["Age_fillna_1"].plot.hist()
titanic["Age"].plot.hist().legend(["com fill", "sem fill"])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
titanic["Age_fillna_mean"] = titanic["Age"].fillna(titanic["Age"].mean())

# %%
# %matplotlib notebook
titanic["Age_fillna_mean"].plot.hist()
titanic["Age"].plot.hist().legend(["com fill", "sem fill"])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Agrupando pessoas por sexo
pessoas_por_sexo = titanic.groupby("Sex").count()
pessoas_por_sexo.head()
# Out:
#         PassengerId  Survived  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# Sex
# female          314       314     314   314  261    314    314     314   314
# male            577       577     577   577  453    577    577     577   577
#
#         Cabin  Embarked  Relatives  AgeRange  idades_nao_nulas  Age_fillna_1  \
# Sex
# female     97       312        314       314               261           314
# male      107       577        577       577               453           577
#
#         Age_fillna_mean
# Sex
# female              314
# male                577

# %%
pessoas_por_cabine = titanic.groupby("Cabin")["PassengerId"].count()
pessoas_por_cabine.head(20)
# Out:
# Cabin
# A10     1
# A14     1
# A16     1
# A19     1
# A20     1
# A23     1
# A24     1
# A26     1
# A31     1
# A32     1
# A34     1
# A36     1
# A5      1
# A6      1
# A7      1
# B101    1
# B102    1
# B18     2
# B19     1
# B20     2
# Name: PassengerId, dtype: int64

# %%
pessoas_por_cabine = titanic.groupby("Cabin")["Age"].size()
pessoas_por_cabine.head(20)
# Out:
# Cabin
# A10     1
# A14     1
# A16     1
# A19     1
# A20     1
# A23     1
# A24     1
# A26     1
# A31     1
# A32     1
# A34     1
# A36     1
# A5      1
# A6      1
# A7      1
# B101    1
# B102    1
# B18     2
# B19     1
# B20     2
# Name: Age, dtype: int64

# %%
soma_idade = titanic.groupby("Cabin")["Age"].sum()
soma_idade.head(10)
# Out:
# Cabin
# A10    36.0
# A14     0.0
# A16    48.0
# A19     0.0
# A20    49.0
# A23    80.0
# A24    31.0
# A26    56.0
# A31    40.0
# A32     0.0
# Name: Age, dtype: float64

# %%
media_idade = titanic.groupby("Cabin")["Age"].mean()
media_idade.head(20)
# Out:
# Cabin
# A10     36.0
# A14      NaN
# A16     48.0
# A19      NaN
# A20     49.0
# A23     80.0
# A24     31.0
# A26     56.0
# A31     40.0
# A32      NaN
# A34      4.0
# A36     39.0
# A5      71.0
# A6      28.0
# A7      56.0
# B101    35.0
# B102     NaN
# B18     30.0
# B19     61.0
# B20     24.0
# Name: Age, dtype: float64

# %%
def contar_pessoas(registros_agrupados):
    return registros_agrupados["PassengerId"].size

pessoas_por_cabine_apply = titanic.groupby("Cabin").apply(contar_pessoas)
pessoas_por_cabine_apply.head(10)
# Out:
# Cabin
# A10    1
# A14    1
# A16    1
# A19    1
# A20    1
# A23    1
# A24    1
# A26    1
# A31    1
# A32    1
# dtype: int64

# %%
def somar_idades(registros_agrupados):
    return registros_agrupados["Age"].sum()

soma_idades_agrupado_cabine_apply = titanic.groupby("Cabin").apply(somar_idades)
soma_idades_agrupado_cabine_apply.describe()
# Out:
# count    147.000000
# mean      45.091293
# std       26.172014
# min        0.000000
# 25%       28.500000
# 50%       44.000000
# 75%       59.250000
# max      130.000000
# dtype: float64

# %%
soma_idade_apply_certo = titanic.groupby("Sex")["PassengerId"].count()
soma_idade_apply_certo
# Out:
# Sex
# female    314
# male      577
# Name: PassengerId, dtype: int64

# %%
def count_sex(registros):
    return registros["Sex"].count()

titanic.groupby("Sex").apply(count_sex)
# Out:
# Sex
# female    314
# male      577
# dtype: int64

# %%
# %matplotlib inline
soma_idade_apply_certo.plot.pie()

# %%
titanic.groupby("AgeRange")["PassengerId"].count()
# Out:
# AgeRange
# adolescente     51
# adulto         590
# criança         62
# idoso           11
# nada           177
# Name: PassengerId, dtype: int64

# %%
media_mulher = titanic[titanic.Sex=="female"]["Age"].mean() # media idade das mulheres
media_homem =  titanic[titanic.Sex=="male"]["Age"].mean()

# %%
def preenche_idade(linha):
    idade = linha["Age"]
    sexo = linha["Sex"]
    
    if pandas.isnull(idade):
        if sexo == "female":
            return media_mulher
        else:
            return media_homem

idades_preenchidas = titanic.apply(preenche_idade, axis=1)

print("""
    Quantidade de nulos apos o preenchimento: {}
""".format(idades_preenchidas.isnull().sum())
)
# Out:
#     Quantidade de nulos apos o preenchimento: 714

# %%
titanic["Age_fillna_mean_sex"] = idades_preenchidas

# %%
titanic[["Age", "Age_fillna_mean_sex"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-148-47455f994746> in <module>
# ----> 1 titanic[["Age", "Age_fillna_mean_sex"]]
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# -> 2726             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2727             return self._take(indexer, axis=1)
#    2728
#
# ...

# %%
titanic.to_csv("titanic_2_aula.csv", index=False)
